# %%
from smolagents import CodeAgent, DuckDuckGoSearchTool, tool, LiteLLMModel
import wikipediaapi

# Naya model
model = LiteLLMModel(
    model_id="groq/llama-3.1-8b-instant",
    api_key="YOUR_GROQ_API_KEY_HERE"
)

@tool
def wikipedia_search(query: str) -> str:
    """
    Searches Wikipedia for information.
    Args:
        query: Topic to search
    """
    wiki = wikipediaapi.Wikipedia(
        user_agent='GAIA-AI-Agent/1.0',
        language='en'
    )
    page = wiki.page(query)
    if page.exists():
        return page.summary[:1000]
    return "No Wikipedia page found"

@tool
def calculate(expression: str) -> str:
    """
    Calculates math expression.
    Args:
        expression: Math like '2+2'
    """
    try:
        return str(eval(expression))
    except:
        return "Invalid expression"

agent = CodeAgent(
    tools=[DuckDuckGoSearchTool(), wikipedia_search, calculate],
    model=model,
    max_steps=5
)

questions = [
    "Who invented the telephone?",
    "What is 144 multiplied by 5?"
]

for i, question in enumerate(questions):
    print(f"\n--- Question {i+1} ---")
    print(f"Q: {question}")
    try:
        answer = agent.run(question)
        print(f"A: {answer}")
    except Exception as e:
        print(f"Error: {e}")

print("\nAll done!")
# Out:
# --- Question 1 ---
# Q: Who invented the telephone?
# ╭──────────────────────────────────────────────────── New run ────────────────────────────────────────────────────╮
# │                                                                                                                 │
# │ Who invented the telephone?                                                                                     │
# │                                                                                                                 │
# ╰─ LiteLLMModel - groq/llama-3.1-8b-instant ──────────────────────────────────────────────────────────────────────╯
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 1 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   results = web_search(query="who invented the telephone")
#   print(results)
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Execution logs:
# ## Search Results
#
# [Alexander Graham Bell - Wikipedia](https://en.wikipedia.org/wiki/Alexander_Graham_Bell)
# Alexander Graham Bell (/ ˈɡreɪ.əm / ⓘ; born Alexander Bell; March 3, 1847 – August 2, 1922) [4] was a Scottish-born
# [N 1] Canadian-American inventor, scientist, and engineer who is credited with patenting the first practical
# telephone. He also co-founded the American Telephone and Telegraph Company (AT&T) in 1885. [7]
#
# [Invention of the telephone - Wikipedia](https://en.wikipedia.org/wiki/Invention_of_the_telephone)
# The invention of the telephone was the culmination of work done by more than one individual, and led to an array of
# lawsuits relating to the patent ...
#
# [Who really invented the telephone? - BBC Science Focus
# Magazine](https://www.sciencefocus.com/science/who-really-invented-the-telephone)
# Jul 14, 2023 · Who invented the telephone? Scottish engineer Alexander Graham Bell is credited with inventing the
# telephone, patenting the world's first telephone on 7 March 1876.
#
# [Alexander Graham Bell’s Telephone Invention Was
# Genius](https://www.belllegacy.org/articles/alex-graham-bell-telephone-invention/)
# Jul 12, 2022 · Alexander Graham Bell’s telephone invention amazed visitors at The Centennial International
# Exhibition of 1876. Though inventions like the Corliss steam engine seemed to be the mightiest, the telephone
# commanded attention for its utility to the average person.
#
# [Alexander Graham Bell: The Life and Times of the Man Who Invented the Telephone
# (book)](https://grokipedia.com/page/alexander_graham_bell_the_life_and_times_of_the_man_who_invented_the_telephone_
# (book))
# Alexander Graham Bell: The Life and Times of the Man Who Invented the Telephone is a 1997 illustrated biography of
# inventor Alexander Graham Bell (1847–1922), co-authored by his great-grandson Edwin S. Grosvenor and documentary
# filmmaker Morgan We…
#
# [Who is credited with inventing the telephone? | Library of
# ...](https://www.loc.gov/everyday-mysteries/technology/item/who-is-credited-with-inventing-the-telephone/)
# Bell is known as the father of the telephone as his design was the first to be patented, and it was Bell who
# continued the work beyond this patent to make a working device that would revolutionize the way we communicate.
#
# [Alexander Graham Bell | Biography, Education, Family ...Alexander Graham Bell: Telephone & Inventions | HISTORYThe
# History of the Telephone and How It Was Invented - ThoughtCoAlexander Graham Bell’s Telephone Invention Was
# Genius](https://www.britannica.com/biography/Alexander-Graham-Bell)
# Apr 14, 2026 · Alexander Graham Bell (1847–1922) was a British-American inventor, scientist, and teacher of the
# deaf whose foremost accomplishments were the invention of the telephone (1876) and refinement of the phonograph
# (1886). Nov 9, 2009 · Alexander Graham Bell, best known for his invention of the telephone, revolutionized
# communication as we know it. His interest in sound technology was deep-rooted and personal, as both his wife... Sep
# 20, 2024 · Alexander Graham Bell beat Elisha Gray in patenting the telephone, dominating its history. Bell's
# knowledge of sound helped him improve the telegraph, leading to the telephone's invention. The invention of the
# telephone led to rapid industry growth, eventually forming AT&T's monopoly. When was the first telephone invented?
# Soon, however, the paper was replaced by a receiver that created more pronounced beeping sounds. In 1876, after
# years of experimenting with sound devices, Alexander Graham Bell was issued the first patent for the telephone.
# Alexander Graham Bell made the first long-distance telephone call in 1892, reaching Chicago from New York. Did
# Alexander Graham Bell invent the telephone? Without the work of other pioneering scientists and inventors,
# Alexander Graham Bell would not have designed the telephone as he did in 1876. Various key players came before him
# and deserve big credit for the overall invention of the telephone. Who patented the telephone? However, the
# question of priority of invention between the two has been controversial from the very beginning. Alexander Graham
# Bell Alexander Graham Bell, inventor who patented the telephone in 1876, lecturing at Salem, Massachusetts (top),
# while friends in his study at Boston listen to his lecture via telephone, February 12, 1877. When was the first
# phone call made? Bell made public demonstrations of his now patented invention, culminating in the world's first
# long distance call, to Paris, 13 kilometres away, on 10 August ^ MacLeod 1999, p. 14. ^ Popular Mechanics Aug 1912.
# New York: Popular Mechanics. August 1912. p. 186. ^ "First Phone Call". ^ Lapsley, Phil (January 8, 2011). Jul 12,
# 2022 · Alexander Graham Bell’s telephone invention amazed visitors at The Centennial International Exhibition of
# 1876. Though inventions like the Corliss steam engine seemed to be the mightiest, the telephone commanded attention
# for its utility to the average person.
#
# [Alexander Graham Bell: Telephone & Inventions | HISTORY](https://www.history.com/articles/alexander-graham-bell)
# Nov 9, 2009 · Alexander Graham Bell, best known for his invention of the telephone, revolutionized communication as
# we know it. His interest in sound technology was deep-rooted and personal, as both his wife...
#
# [The History of the Telephone and How It Was Invented -
# ThoughtCo](https://www.thoughtco.com/history-of-the-telephone-alexander-graham-bell-1991380)
# Sep 20, 2024 · Alexander Graham Bell beat Elisha Gray in patenting the telephone, dominating its history. Bell's
# knowledge of sound helped him improve the telegraph, leading to the telephone's invention. The invention of the
# telephone led to rapid industry growth, eventually forming AT&T's monopoly.
#
# [Who is credited with inventing the telephone? | Library
# of](https://www.loc.gov/everyday-mysteries/technology/item/who-is-credited-with-inventing-the-telephone)
# ... inventor who is sometimes cited as another candidate to be the ... Alexander Graham Bell: the life and times of
# the man who invented the telephone .
#
# Out: None
# [Step 1: Duration 6.00 seconds| Input tokens: 2,123 | Output tokens: 116]
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 2 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# Give Feedback / Get Help: https://github.com/BerriAI/litellm/issues/new
# LiteLLM.Info: If you need to debug this error, use `litellm._turn_on_debug()'.
#
#
# Provider List: https://docs.litellm.ai/docs/providers
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   final_answer("Alexander Graham Bell")
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Final answer: Alexander Graham Bell
# [Step 2: Duration 197.86 seconds| Input tokens: 5,712 | Output tokens: 155]
# A: Alexander Graham Bell
#
# --- Question 2 ---
# Q: What is 144 multiplied by 5?
# ╭──────────────────────────────────────────────────── New run ────────────────────────────────────────────────────╮
# │                                                                                                                 │
# │ What is 144 multiplied by 5?                                                                                    │
# │                                                                                                                 │
# ╰─ LiteLLMModel - groq/llama-3.1-8b-instant ──────────────────────────────────────────────────────────────────────╯
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 1 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   result = calculate("144 * 5")
#   final_answer(result)
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Final answer: 720
# [Step 1: Duration 0.37 seconds| Input tokens: 2,127 | Output tokens: 49]
# A: 720
#
# All done!
