# %%
# !pip install smolagents
# !pip install huggingface_hub

# %%
# !pip install smolagents --upgrade

# %%
import smolagents
print(dir(smolagents))

# %%
# !pip install duckduckgo-search

# %%
# !pip install ddgs

# %%
1. huggingface.co/settings/tokens
2. New Token: Click
3. Name: "jupyter-agent"
4. Role: Read
5. Generate: Copy karo

# %%
from smolagents import (
    CodeAgent, 
    InferenceClientModel,
    DuckDuckGoSearchTool
)

model = InferenceClientModel(
    model_id="Qwen/Qwen2.5-72B-Instruct",
    token="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"
)

tools = [DuckDuckGoSearchTool()]

agent = CodeAgent(
    tools=tools,
    model=model,
    max_steps=5
)

result = agent.run("What is the capital of France?")
print(result)

# %%
# !pip install datasets

# %%
from huggingface_hub import login
login(token="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")

# %%
from huggingface_hub import login
login(token="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")

# %%
from datasets import load_dataset

dataset = load_dataset(
    "gaia-benchmark/GAIA",
    "2023_all",
)

print(dataset)

# %%
print(dataset["validation"][0])

# %%
import json

answers = []

# Sirf pehle 20 questions karo pehle
for task in dataset["validation"].select(range(20)):
    task_id = task["task_id"]
    question = task["Question"]
    
    try:
        answer = agent.run(question)
        answers.append({
            "task_id": task_id,
            "model_answer": str(answer),
            "reasoning_trace": "smolagents"
        })
        print(f"✅ Done: {task_id}")
    except Exception as e:
        answers.append({
            "task_id": task_id,
            "model_answer": "",
            "reasoning_trace": str(e)
        })
        print(f"❌ Error: {task_id}")

# JSON save karo
with open("answers.json", "w") as f:
    json.dump(answers, f)

print("Done! answers.json ready!")

# %%
import json

with open("answers.json", "r") as f:
    data = json.load(f)
    
print(f"Total answers: {len(data)}")
print(data)

# %%
# Cell 1 - Imports
from smolagents import (
    CodeAgent,
    InferenceClientModel,
    DuckDuckGoSearchTool
)
from huggingface_hub import login
from datasets import load_dataset
import json

# Cell 2 - Login
login(token="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")

# Cell 3 - Model
model = InferenceClientModel(
    model_id="Qwen/Qwen2.5-72B-Instruct",
    token="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"
)

# Cell 4 - Agent
tools = [DuckDuckGoSearchTool()]
agent = CodeAgent(
    tools=tools,
    model=model,
    max_steps=3  # 5 se 3 kar diya — faster!
)

# Cell 5 - Sirf 3 Questions!
dataset = load_dataset("gaia-benchmark/GAIA", "2023_all")
answers = []

for task in dataset["validation"].select(range(3)):
    try:
        answer = agent.run(task["Question"])
        answers.append({
            "task_id": task["task_id"],
            "model_answer": str(answer),
            "reasoning_trace": "smolagents"
        })
        print(f"✅ Done!")
    except Exception as e:
        answers.append({
            "task_id": task["task_id"],
            "model_answer": "",
            "reasoning_trace": "error"
        })
        print(f"❌ Error!")

with open("answers.json", "w") as f:
    json.dump(answers, f)
print("Done!")
# Out:
# ╭──────────────────────────────────────────────────── New run ────────────────────────────────────────────────────╮
# │                                                                                                                 │
# │ A paper about AI regulation that was originally submitted to arXiv.org in June 2022 shows a figure with three   │
# │ axes, where each axis has a label word at both ends. Which of these words is used to describe a type of society │
# │ in a Physics and Society article submitted to arXiv.org on August 11, 2016?                                     │
# │                                                                                                                 │
# ╰─ InferenceClientModel - Qwen/Qwen2.5-72B-Instruct ──────────────────────────────────────────────────────────────╯
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 1 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# ...

# %%
import os
print(os.getcwd())
# Out:
# C:\Users\Dhananjay

# %%
import os
files = os.listdir()
print(files)
# Out:
# ['-1.14-windows.xml', '.anaconda', '.antigravity', '.cache', '.conda', '.continuum', '.eclipse', '.fastai', '.gemini', '.gitconfig', '.idlerc', '.ipynb_checkpoints', '.ipython', '.jupyter', '.lc', '.matplotlib', '.p2', '.skiko', '.VirtualBox', '.vscode', '.vscode-shared', '100-days-of-ml', 'anaconda3', 'ansel', 'answers.json', 'AppData', 'Application Data', 'aug_test.csv', 'aug_train.csv (1).zip', 'cars.csv', 'category_bar.png', 'Contacts', 'Cookies', 'customer (1).csv', 'customers.csv', 'dashboard.html', 'Desktop', 'Documents', 'Downloads', 'EDA using Univariant Analysis', 'Favorites', 'firstprogram.py', 'jay firstprogram.py', 'Links', 'Local Settings', 'model.pkl', 'Music', 'My Documents', 'NetHood', 'Normalization .ipynb', 'Normalization.lecture no.25', 'NTUSER.DAT', 'ntuser.dat.LOG1', 'ntuser.dat.LOG2', 'NTUSER.DAT{3fcb4baa-6db5-11f0-9fda-a013308ceca4}.TM.blf', 'NTUSER.DAT{3fcb4baa-6db5-11f0-9fda-a013308ceca4}.TMContainer00000000000000000001.regtrans-ms', 'NTUSER.DAT{3fcb4baa-6db
# ...

# %%
os.getcwd()
# Out:
# 'C:\\Users\\Dhananjay'

# %%
GAIA_A
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 GAIA_Agent.ipynb
#
# NameError: name 'GAIA_Agent' is not defined
